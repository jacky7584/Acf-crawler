# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from requests.packages import urllib3
from selenium import webdriver
from selenium.webdriver.edge.options import Options
from selenium.webdriver.common.by import By 
import time
import os
from selenium.webdriver.edge.options import Options
from selenium.webdriver.common.by import By
import time

# %%
proxy = "10.11.1.78:8080"
proxies = {
    "http": "http://" + proxy,
    "https": "http://" + proxy,
}
response = requests.get("https://websys.fsit.com.tw/FubonETF/Trade/Pcf.aspx?stkId=00694B&lan=TW",proxies=proxies)
a1=[]
b1=[]
content = BeautifulSoup(response.text, "html.parser")
p=content.find_all("p")
for i in range(len(p)):
    if "已發行受益權單位總數" in p[i].get_text():
        print(p[i].get_text(),print(p[i+1].get_text()))
        a1.append(p[i+1].get_text())
    elif "預估發行受益權單位數" in p[i].get_text():
        print(p[i].get_text(),print(p[i+1].get_text()))
        b1.append(p[i+1].get_text())
# Out:
# 93,076,000
# 已發行受益權單位總數 None
# 93,076,000
# 2023/10/06 預估發行受益權單位數 None

# %%
table[0].find_all("th")
# Out:
# [<th class="b-align-center" colspan="2"><em>台新美元銀行債券15年期以上ETF基金 (證券代號:00842B) 2023/10/11 現金申購買回清單公告 </em></th>,
#  <th><em class="set-default">每申購基數之需預收申購總價金(元)</em></th>,
#  <th><em class="set-default">基金淨資產價值</em></th>,
#  <th><em class="set-default">已發行受益權單位總數</em></th>,
#  <th><em class="set-default">與前日已發行單位差異數</em></th>,
#  <th><em class="set-default">每受益權單位淨資產價值</em></th>,
#  <th><em class="set-default">每現金申購/買回基數之受益權單位數</em></th>,
#  <th><em class="set-default">每現金申購/買回基數約當市值</em></th>,
#  <th><em class="set-default">每現金申購基數總價金差異額</em></th>,
#  <th><em class="set-default">每申購基數實際申購總價金</em></th>,
#  <th><em class="set-default">2023/10/06預估發行受益權單位數</em></th>]

# %%
table[0].find_all("td")
# Out:
# [<td><em class="set-default">NT$15,749,288</em></td>,
#  <td><em class="set-default">NT$277,962,127</em></td>,
#  <td><em class="set-default">9,267,000</em></td>,
#  <td><em class="set-default">0</em></td>,
#  <td><em class="set-default">NT$29.99</em></td>,
#  <td><em class="set-default">500,000</em></td>,
#  <td><em class="set-default">14,997,417</em></td>,
#  <td><em class="set-default">-685,213</em></td>,
#  <td><em class="set-default">15,026,982</em></td>,
#  <td><em class="set-default">9,767,000</em></td>]

# %% [markdown]
# # 元大

# %%
#name=["00679B","00681R","00719B","00721B","00786B","00788B","00680L","00697B","00720B","00751B","00787B","00870B"]
name=["00679B"]
domain="https://www.yuantaetfs.com/tradeInfo/pcf/"
a1=[]
b1=[]
ck=0
for i in name:
    url=domain+i
    response = requests.get(url)
    content = BeautifulSoup(response.text, "html.parser")
    table = content.find_all(class_="td")
    print(table)
    for j in table:
        try:
            h4=table.find("h4").get_text()
            p=table.find("p").get_text()
            if h4=="已發行受益權單位總數":
                a1.append(p)
            elif h4=="預估發行受益權單位數":
                b1.append(p)
        except:
            pass

# ans=pd.DataFrame()
# ans['name']=name
# ans["已發行受益權單位總數"]=a1
# ans["預估發行受益權單位數"]=b1
# ans
# Out:
# [<div class="td" data-v-748178ef=""><h4 data-v-748178ef="">已發行受益權單位總數</h4> <p data-v-748178ef="">3,999,692,000</p></div>, <div class="td" data-v-748178ef=""><h4 data-v-748178ef="">與前日已發行單位差異數</h4> <p data-v-748178ef="">0.00</p></div>, <div class="td" data-v-748178ef=""><h5 data-v-748178ef="">2023/10/11</h5> <h4 data-v-748178ef="">
#           每受益權單位淨資產價值(元)
#         </h4> <p data-v-748178ef="">NTD 28.2737</p></div>, <div class="td" data-v-748178ef=""><h4 data-v-748178ef="">每現金申購單位之受益權單位數</h4> <p data-v-748178ef="">500,000</p></div>, <div class="td" data-v-748178ef=""><h4 data-v-748178ef="">每現金申購單位約當市值(元)</h4> <p data-v-748178ef="">NTD 14,136,836</p></div>, <div class="td" data-v-748178ef=""><h4 data-v-748178ef="">每申購基數之預收申購總價金(元)</h4> <p data-v-748178ef="">NTD 15,280,000</p></div>, <div class="td" data-v-748178ef=""><h5 data-v-748178ef="">2023/10/11</h5> <h4 data-v-748178ef="">
#           每基數申購總價金差異額(元)
#         </h4> <p data-v-748178ef="">NTD -778,163</p></div>, <div class="td" data-v-748178ef=""><h5 data-v-748178ef="">2023/10/11</h5> <h4 data-v-748178ef="">
#           每基數實際申購總價金(元)
#         </h4> <p data-v-748178ef="">NTD 14,141,837</p></div>, <div class="td" data-v-748178ef=""><h5 data-v-748178ef="">2023/10/12</h5> <h4 data-v-748178ef="">預估發行受益權單位數</h4> <p data-v-748178ef="">3,999,692,000</p></div>, <div class="td" data-v-748178ef=""><h5 data-v-748178ef="">2023/09/30</h5> <h4 data-v-748178ef="">
#           受益人數
#         </h4> <p data-v-748178ef="">196201</p></div>, <div class="td" data-v-4dc52081="">
#             商品代碼
#           </div>, <div class="td" data-v-4dc52081="">
#             商品名稱
#           </div>, <div class="td" data-v-4dc52081="">
#             面額
#           </div>, <div class="td" data-v-4dc52081="">
#             市值
#           </div>, <div class="td" data-v-4dc52081="">
#             商品權重
#           </div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品代碼</span> <span data-v-4dc52081="">912810TL2</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品名稱</span> <span data-v-4dc52081="">US TREASURY N/B 4% 11/15/2052</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">面額</span> <span data-v-4dc52081="">276500000</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">市值</span> <span data-v-4dc52081="">249502271.19</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品權重</span> <span data-v-4dc52081="">7.08</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品代碼</span> <span data-v-4dc52081="">912810TN8</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品名稱</span> <span data-v-4dc52081="">US TREASURY N/B 3.625% 02/15/2053</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">面額</span> <span data-v-4dc52081="">285200000</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">市值</span> <span data-v-4dc52081="">237409625</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品權重</span> <span data-v-4dc52081="">6.74</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品代碼</span> <span data-v-4dc52081="">912810TR9</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品名稱</span> <span data-v-4dc52081="">US TREASURY N/B 3.625% 05/15/2053</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">面額</span> <span data-v-4dc52081="">250300000</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">市值</span> <span data-v-4dc52081="">210782527.18</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品權重</span> <span data-v-4dc52081="">5.98</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品代碼</span> <span data-v-4dc52081="">912810TJ7</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品名稱</span> <span data-v-4dc52081="">US TREASURY N/B 3% 08/15/2052</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">面額</span> <span data-v-4dc52081="">284100000</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">市值</span> <span data-v-4dc52081="">208392270.86</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品權重</span> <span data-v-4dc52081="">5.92</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品代碼</span> <span data-v-4dc52081="">912810TG3</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品名稱</span> <span data-v-4dc52081="">US TREASURY N/B 2.875% 05/15/2052</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">面額</span> <span data-v-4dc52081="">253325000</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">市值</span> <span data-v-4dc52081="">182492953.81</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品權重</span> <span data-v-4dc52081="">5.18</span></div>, <div class="td" data-v-4dc52081="">
#             檔數
#           </div>, <div class="td" data-v-4dc52081="">
#             評比
#           </div>, <div class="td" data-v-4dc52081="">
#             比例
#           </div>, <div class="td" data-v-4dc52081="">
#             日期
#           </div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">檔數</span> <span data-v-4dc52081="">40</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">評比</span> <span data-v-4dc52081="">AAA</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">比例</span> <span data-v-4dc52081="">98.78</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">日期</span> <span data-v-4dc52081="">20231011</span></div>, <div class="td" data-v-4dc52081="">
#             名稱
#           </div>, <div class="td" data-v-4dc52081="">
#             比例
#           </div>, <div class="td" data-v-4dc52081="">
#             檔數
#           </div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">名稱</span> <span data-v-4dc52081="">美國</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">比例</span> <span data-v-4dc52081="">98.78</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">檔數</span> <span data-v-4dc52081="">40</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">名稱</span> <span data-v-4dc52081="">現金</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">比例</span> <span data-v-4dc52081="">1.22</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">檔數</span> <span data-v-4dc52081="">0</span></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">台幣</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">韓元</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">日圓</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">港幣</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">歐元</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">人民幣</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">離岸人民幣</h4></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">台幣</h4> <p data-v-691531c5="">32.104</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">韓元</h4> <p data-v-691531c5="">1340.13</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">日圓</h4> <p data-v-691531c5="">148.76</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">港幣</h4> <p data-v-691531c5="">7.8193</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">歐元</h4> <p data-v-691531c5="">0.9434</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">人民幣</h4> <p data-v-691531c5="">7.2986</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">離岸人民幣</h4> <p data-v-691531c5="">7.2987</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">基金淨資產價值</h4> <p data-v-2f2fbab0="">NTD $113,085,980,763.00</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">每受益權單位淨資產價值(元)</h4> <p data-v-2f2fbab0="">NTD $28.2737</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">已發行受益權單位總數</h4> <p data-v-2f2fbab0="">3,999,692,000</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">股票</h4> <p data-v-2f2fbab0="">NTD $0.00</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">期貨</h4> <p data-v-2f2fbab0="">NTD $0.00</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">ETF</h4> <p data-v-2f2fbab0="">NTD $0.00</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">債券</h4> <p data-v-2f2fbab0="">NTD $112,973,016,436.80</p></div>, <div class="td cash" data-v-2f2fbab0=""><!-- --> <h4 data-v-2f2fbab0="">保證金</h4> <p data-v-2f2fbab0="">USD $5.14</p></div>, <div class="td cash" data-v-2f2fbab0=""><!-- --> <h4 data-v-2f2fbab0="">現金</h4> <p data-v-2f2fbab0="">NTD $105,144,559.00</p></div>, <div class="td cash" data-v-2f2fbab0=""><!-- --> <h4 data-v-2f2fbab0="">應收利息</h4> <p data-v-2f2fbab0="">USD $39,546,357.27</p></div>, <div class="td" data-v-2f2fbab0="">名稱</div>, <div class="td" data-v-2f2fbab0="">元大美國政府20年期(以上)債券基金</div>, <div class="td" data-v-2f2fbab0="">ICE美國政府20+年期債券指數</div>, <div class="td" data-v-2f2fbab0="">差異< ...
# [<div class="td" data-v-748178ef=""><h4 data-v-748178ef="">已發行受益權單位總數</h4> <p data-v-748178ef="">11,094,000</p></div>, <div class="td" data-v-748178ef=""><h4 data-v-748178ef="">與前日已發行單位差異數</h4> <p data-v-748178ef="">0.00</p></div>, <div class="td" data-v-748178ef=""><h5 data-v-748178ef="">2023/10/11</h5> <h4 data-v-748178ef="">
#           每受益權單位淨資產價值(元)
#         </h4> <p data-v-748178ef="">NTD 21.5434</p></div>, <div class="td" data-v-748178ef=""><h4 data-v-748178ef="">每現金申購單位之受益權單位數</h4> <p data-v-748178ef="">500,000</p></div>, <div class="td" data-v-748178ef=""><h4 data-v-748178ef="">每現金申購單位約當市值(元)</h4> <p data-v-748178ef="">NTD 10,771,706</p></div>, <div class="td" data-v-748178ef=""><h4 data-v-748178ef="">每申購基數之預收申購總價金(元)</h4> <p data-v-748178ef="">NTD 11,640,000</p></div>, <div class="td" data-v-748178ef=""><h5 data-v-748178ef="">2023/10/11</h5> <h4 data-v-748178ef="">
#           每基數申購總價金差異額(元)
#         </h4> <p data-v-748178ef="">NTD -1,162,138</p></div>, <div class="td" data-v-748178ef=""><h5 data-v-748178ef="">2023/10/11</h5> <h4 data-v-748178ef="">
#           每基數實際申購總價金(元)
#         </h4> <p data-v-748178ef="">NTD 10,777,862</p></div>, <div class="td" data-v-748178ef=""><h5 data-v-748178ef="">2023/10/12</h5> <h4 data-v-748178ef="">預估發行受益權單位數</h4> <p data-v-748178ef="">11,094,000</p></div>, <div class="td" data-v-748178ef=""><h5 data-v-748178ef="">2023/09/30</h5> <h4 data-v-748178ef="">
#           受益人數
#         </h4> <p data-v-748178ef="">195</p></div>, <div class="td" data-v-4dc52081="">
#             商品代碼
#           </div>, <div class="td" data-v-4dc52081="">
#             商品名稱
#           </div>, <div class="td" data-v-4dc52081="">
#             商品數量
#           </div>, <div class="td" data-v-4dc52081="">
#             商品權重
#           </div>, <div class="td" data-v-4dc52081="">
#             商品年月
#           </div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品代碼</span> <span data-v-4dc52081="">UB</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品名稱</span> <a data-v-4dc52081="" href="https://www.cmegroup.com/cn-t/trading/interest-rates/us-treasury/ultra-t-bond_quotes_globex.html"> 美國超長期政府債券期貨</a></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品數量</span> <span data-v-4dc52081="">-65</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品權重</span> <span data-v-4dc52081="">103.11</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品年月</span> <span data-v-4dc52081="">202312</span></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">台幣</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">韓元</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">日圓</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">港幣</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">歐元</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">人民幣</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">離岸人民幣</h4></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">台幣</h4> <p data-v-691531c5="">32.104</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">韓元</h4> <p data-v-691531c5="">1340.13</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">日圓</h4> <p data-v-691531c5="">148.76</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">港幣</h4> <p data-v-691531c5="">7.8193</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">歐元</h4> <p data-v-691531c5="">0.9434</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">人民幣</h4> <p data-v-691531c5="">7.2986</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">離岸人民幣</h4> <p data-v-691531c5="">7.2987</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">基金淨資產價值</h4> <p data-v-2f2fbab0="">NTD $239,002,623.00</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">每受益權單位淨資產價值(元)</h4> <p data-v-2f2fbab0="">NTD $21.5434</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">已發行受益權單位總數</h4> <p data-v-2f2fbab0="">11,094,000</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">股票</h4> <p data-v-2f2fbab0="">NTD $0.00</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">期貨</h4> <p data-v-2f2fbab0="">NTD $246,433,313.75</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">ETF</h4> <p data-v-2f2fbab0="">NTD $0.00</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">債券</h4> <p data-v-2f2fbab0="">NTD $0.00</p></div>, <div class="td cash" data-v-2f2fbab0=""><!-- --> <h4 data-v-2f2fbab0="">保證金</h4> <p data-v-2f2fbab0="">NTD $24,105,023.00</p></div>, <div class="td cash" data-v-2f2fbab0=""><!-- --> <h4 data-v-2f2fbab0="">保證金</h4> <p data-v-2f2fbab0="">USD $1,503,297.62</p></div>, <div class="td cash" data-v-2f2fbab0=""><!-- --> <h4 data-v-2f2fbab0="">現金</h4> <p data-v-2f2fbab0="">NTD $166,190,530.00</p></div>, <div class="td cash" data-v-2f2fbab0=""><!-- --> <h4 data-v-2f2fbab0="">現金</h4> <p data-v-2f2fbab0="">USD $11,840.04</p></div>, <div class="td cash" data-v-2f2fbab0=""><!-- --> <h4 data-v-2f2fbab0="">應收利息</h4> <p d ...
# [<div class="td" data-v-748178ef=""><h4 data-v-748178ef="">已發行受益權單位總數</h4> <p data-v-748178ef="">163,514,000</p></div>, <div class="td" data-v-748178ef=""><h4 data-v-748178ef="">與前日已發行單位差異數</h4> <p data-v-748178ef="">-5,000,000</p></div>, <div class="td" data-v-748178ef=""><h5 data-v-748178ef="">2023/10/11</h5> <h4 data-v-748178ef="">
#           每受益權單位淨資產價值(元)
#         </h4> <p data-v-748178ef="">NTD 31.6567</p></div>, <div class="td" data-v-748178ef=""><h4 data-v-748178ef="">每現金申購單位之受益權單位數</h4> <p data-v-748178ef="">500,000</p></div>, <div class="td" data-v-748178ef=""><h4 data-v-748178ef="">每現金申購單位約當市值(元)</h4> <p data-v-748178ef="">NTD 15,828,341</p></div>, <div class="td" data-v-748178ef=""><h4 data-v-748178ef="">每申購基數之預收申購總價金(元)</h4> <p data-v-748178ef="">NTD 16,310,000</p></div>, <div class="td" data-v-748178ef=""><h5 data-v-748178ef="">2023/10/11</h5> <h4 data-v-748178ef="">
#           每基數申購總價金差異額(元)
#         </h4> <p data-v-748178ef="">NTD -556,565</p></div>, <div class="td" data-v-748178ef=""><h5 data-v-748178ef="">2023/10/11</h5> <h4 data-v-748178ef="">
#           每基數實際申購總價金(元)
#         </h4> <p data-v-748178ef="">NTD 15,833,435</p></div>, <div class="td" data-v-748178ef=""><h5 data-v-748178ef="">2023/10/12</h5> <h4 data-v-748178ef="">預估發行受益權單位數</h4> <p data-v-748178ef="">163,514,000</p></div>, <div class="td" data-v-748178ef=""><h5 data-v-748178ef="">2023/09/30</h5> <h4 data-v-748178ef="">
#           受益人數
#         </h4> <p data-v-748178ef="">3022</p></div>, <div class="td" data-v-4dc52081="">
#             商品代碼
#           </div>, <div class="td" data-v-4dc52081="">
#             商品名稱
#           </div>, <div class="td" data-v-4dc52081="">
#             面額
#           </div>, <div class="td" data-v-4dc52081="">
#             市值
#           </div>, <div class="td" data-v-4dc52081="">
#             商品權重
#           </div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品代碼</span> <span data-v-4dc52081="">91282CHB0</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品名稱</span> <span data-v-4dc52081="">US TREASURY N/B 3.625% 05/15/2026</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">面額</span> <span data-v-4dc52081="">6930000</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">市值</span> <span data-v-4dc52081="">6830722.52</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品權重</span> <span data-v-4dc52081="">4.24</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品代碼</span> <span data-v-4dc52081="">91282CHM6</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品名稱</span> <span data-v-4dc52081="">US TREASURY N/B 4.5% 07/15/2026</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">面額</span> <span data-v-4dc52081="">6280000</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">市值</span> <span data-v-4dc52081="">6299283.7</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品權重</span> <span data-v-4dc52081="">3.91</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品代碼</span> <span data-v-4dc52081="">91282CGX3</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品名稱</span> <span data-v-4dc52081="">US TREASURY N/B 3.875% 04/30/2025</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">面額</span> <span data-v-4dc52081="">6250000</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">市值</span> <span data-v-4dc52081="">6239448.88</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品權重</span> <span data-v-4dc52081="">3.87</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品代碼</span> <span data-v-4dc52081="">91282CHH7</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品名稱</span> <span data-v-4dc52081="">US TREASURY N/B 4.125% 06/15/2026</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">面額</span> <span data-v-4dc52081="">6150000</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">市值</span> <span data-v-4dc52081="">6127260.4</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品權重</span> <span data-v-4dc52081="">3.8</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品代碼</span> <span data-v-4dc52081="">91282CGV7</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品名稱</span> <span data-v-4dc52081="">US TREASURY N/B 3.75% 04/15/2026</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">面額</span> <span data-v-4dc52081="">6010000</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">市值</span> <span data-v-4dc52081="">5965190.54</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品權重</span> <span data-v-4dc52081="">3.7</span></div>, <div class="td" data-v-4dc52081="">
#             檔數
#           </div>, <div class="td" data-v-4dc52081="">
#             評比
#           </div>, <div class="td" data-v-4dc52081="">
#             比例
#           </div>, <div class="td" data-v-4dc52081="">
#             日期
#           </div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">檔數</span> <span data-v-4dc52081="">64</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">評比</span> <span data-v-4dc52081="">AAA</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">比例</span> <span data-v-4dc52081="">94.51</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">日期</span> <span data-v-4dc52081="">20231011</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">檔數</span> <span data-v-4dc52081="">2</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">評比</span> <span data-v-4dc52081="">AA</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">比例</span> <span data-v-4dc52081="">3.79</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">日期</span> <span data-v-4dc52081="">20231011</span></div>, <div class="td" data-v-4dc52081="">
#             名稱
#           </div>, <div class="td" data-v-4dc52081="">
#             比例
#           </div>, <div class="td" data-v-4dc52081="">
#             檔數
#           </div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">名稱</span> <span data-v-4dc52081="">美國</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">比例</span> <span data-v-4dc52081="">98.3</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">檔數</span> <span data-v-4dc52081="">66</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">名稱</span> <span data-v-4dc52081="">現金</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">比例</span> <span data-v-4dc52081="">1.7</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">檔數</span> <span data-v-4dc52081="">0</span></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">台幣</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">韓元</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">日圓</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">港幣</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">歐元</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">人民幣</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">離岸人民幣</h4></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">台幣</h4> <p data-v-691531c5="">32.104</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">韓元</h4> <p data-v-691531c5="">1340.13</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">日圓</h4> <p data-v-691531c5="">148.76</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">港幣</h4> <p data-v-691531c5="">7.8193</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">歐元</h4> <p data-v-691531c5="">0.9434</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">人民幣</h4> <p data-v-691531c5="">7.2986</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">離岸人民幣</h4> <p data-v-691531c5="">7.2987</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">基金淨資產價值</h4> <p data-v-2f2fbab0="">NTD $5,176,310,709.00</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">每受益權單位淨資產價值(元)</h4> <p data-v-2f2fbab0="">NTD $31.6567</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">已發行受益權單位總數</h4> <p data-v-2f2fbab0="">163,514,000</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">股票</h4> <p data-v-2f2fbab0="">NTD $0.00</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">期貨</h4> <p data-v-2f2fbab0="">NTD $0.00</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">ETF</h4> <p data-v-2f2fbab0="">NTD $0.00</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">債券</h4> <p data-v-2f2fbab0="">NTD $5,140,993,121.01</p></div>, <div class="td cash" data-v-2f2fbab0=""><!-- --> <h4 data-v-2f2fbab0="">保證金</h4> <p data-v-2f2fbab0="">NTD $274.00</p></div>, <div class="td cash" data-v-2f2fbab0=""><!-- --> <h4 data-v-2f2fbab0="">現金</h4> <p data-v-2f2fbab0="">NTD $92,356,039.00</p></div>, <div class="td cash" data-v-2f2fbab0=""><!-- --> <h4 data-v-2f2fbab0="">現金</h4> <p data-v-2f2fbab0="">USD $1,039,925.06</p></div>, <div class="td cash" data-v-2f2fbab0=""><!-- --> <h4 data-v-2f2fbab0="">應收利息</h4> <p data-v-2f2fbab0="">USD $1,638,783.57</p></div>, <div class="td cash" data-v-2f2fbab0=""><!-- --> <h4 data-v-2f2fbab0="">應付受益權單位買 ...
# [<div class="td" data-v-748178ef=""><h4 data-v-748178ef="">已發行受益權單位總數</h4> <p data-v-748178ef="">4,622,000</p></div>, <div class="td" data-v-748178ef=""><h4 data-v-748178ef="">與前日已發行單位差異數</h4> <p data-v-748178ef="">0.00</p></div>, <div class="td" data-v-748178ef=""><h5 data-v-748178ef="">2023/10/11</h5> <h4 data-v-748178ef="">
#           每受益權單位淨資產價值(元)
#         </h4> <p data-v-748178ef="">NTD 45.8608</p></div>, <div class="td" data-v-748178ef=""><h4 data-v-748178ef="">每現金申購單位之受益權單位數</h4> <p data-v-748178ef="">500,000</p></div>, <div class="td" data-v-748178ef=""><h4 data-v-748178ef="">每現金申購單位約當市值(元)</h4> <p data-v-748178ef="">NTD 22,930,391</p></div>, <div class="td" data-v-748178ef=""><h4 data-v-748178ef="">每申購基數之預收申購總價金(元)</h4> <p data-v-748178ef="">NTD 24,090,000</p></div>, <div class="td" data-v-748178ef=""><h5 data-v-748178ef="">2023/10/11</h5> <h4 data-v-748178ef="">
#           每基數申購總價金差異額(元)
#         </h4> <p data-v-748178ef="">NTD -1,237,234</p></div>, <div class="td" data-v-748178ef=""><h5 data-v-748178ef="">2023/10/11</h5> <h4 data-v-748178ef="">
#           每基數實際申購總價金(元)
#         </h4> <p data-v-748178ef="">NTD 22,942,766</p></div>, <div class="td" data-v-748178ef=""><h5 data-v-748178ef="">2023/10/12</h5> <h4 data-v-748178ef="">預估發行受益權單位數</h4> <p data-v-748178ef="">4,622,000</p></div>, <div class="td" data-v-748178ef=""><h5 data-v-748178ef="">2023/09/30</h5> <h4 data-v-748178ef="">
#           受益人數
#         </h4> <p data-v-748178ef="">446</p></div>, <div class="td" data-v-4dc52081="">
#             商品代碼
#           </div>, <div class="td" data-v-4dc52081="">
#             商品名稱
#           </div>, <div class="td" data-v-4dc52081="">
#             面額
#           </div>, <div class="td" data-v-4dc52081="">
#             市值
#           </div>, <div class="td" data-v-4dc52081="">
#             商品權重
#           </div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品代碼</span> <span data-v-4dc52081="">BU6756300</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品名稱</span> <span data-v-4dc52081="">CHINA DEVELOPMENT BANK 2.65% 02/24/2027</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">面額</span> <span data-v-4dc52081="">4000000</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">市值</span> <span data-v-4dc52081="">4078034.52</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品權重</span> <span data-v-4dc52081="">8.46</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品代碼</span> <span data-v-4dc52081="">ZJ6881099</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品名稱</span> <span data-v-4dc52081="">CHINA GOVERNMENT BOND 2.4% 07/15/2028</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">面額</span> <span data-v-4dc52081="">4000000</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">市值</span> <span data-v-4dc52081="">3991144.26</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品權重</span> <span data-v-4dc52081="">8.28</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品代碼</span> <span data-v-4dc52081="">AL9715056</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品名稱</span> <span data-v-4dc52081="">AGRICUL DEV BANK CHINA 3.85% 01/06/2027</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">面額</span> <span data-v-4dc52081="">3000000</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">市值</span> <span data-v-4dc52081="">3206996.3</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品權重</span> <span data-v-4dc52081="">6.65</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品代碼</span> <span data-v-4dc52081="">BN2975017</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品名稱</span> <span data-v-4dc52081="">CHINA DEVELOPMENT BANK 3.4% 01/08/2028</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">面額</span> <span data-v-4dc52081="">3000000</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">市值</span> <span data-v-4dc52081="">3169598.22</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品權重</span> <span data-v-4dc52081="">6.58</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品代碼</span> <span data-v-4dc52081="">ZP2934997</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品名稱</span> <span data-v-4dc52081="">CHINA DEVELOPMENT BANK 3.43% 01/14/2027</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">面額</span> <span data-v-4dc52081="">3000000</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">市值</span> <span data-v-4dc52081="">3162049.73</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品權重</span> <span data-v-4dc52081="">6.56</span></div>, <div class="td" data-v-4dc52081="">
#             檔數
#           </div>, <div class="td" data-v-4dc52081="">
#             評比
#           </div>, <div class="td" data-v-4dc52081="">
#             比例
#           </div>, <div class="td" data-v-4dc52081="">
#             日期
#           </div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">檔數</span> <span data-v-4dc52081="">16</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">評比</span> <span data-v-4dc52081="">A</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">比例</span> <span data-v-4dc52081="">96.52</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">日期</span> <span data-v-4dc52081="">20231011</span></div>, <div class="td" data-v-4dc52081="">
#             名稱
#           </div>, <div class="td" data-v-4dc52081="">
#             比例
#           </div>, <div class="td" data-v-4dc52081="">
#             檔數
#           </div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">名稱</span> <span data-v-4dc52081="">中國</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">比例</span> <span data-v-4dc52081="">96.52</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">檔數</span> <span data-v-4dc52081="">16</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">名稱</span> <span data-v-4dc52081="">現金</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">比例</span> <span data-v-4dc52081="">3.48</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">檔數</span> <span data-v-4dc52081="">0</span></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">台幣</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">韓元</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">日圓</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">港幣</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">歐元</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">人民幣</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">離岸人民幣</h4></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">台幣</h4> <p data-v-691531c5="">32.104</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">韓元</h4> <p data-v-691531c5="">1340.13</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">日圓</h4> <p data-v-691531c5="">148.76</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">港幣</h4> <p data-v-691531c5="">7.8193</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">歐元</h4> <p data-v-691531c5="">0.9434</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">人民幣</h4> <p data-v-691531c5="">7.2986</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">離岸人民幣</h4> <p data-v-691531c5="">7.2987</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">基金淨資產價值</h4> <p data-v-2f2fbab0="">NTD $211,968,532.00</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">每受益權單位淨資產價值(元)</h4> <p data-v-2f2fbab0="">NTD $45.8608</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">已發行受益權單位總數</h4> <p data-v-2f2fbab0="">4,622,000</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">股票</h4> <p data-v-2f2fbab0="">NTD $0.00</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">期貨</h4> <p data-v-2f2fbab0="">NTD $0.00</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">ETF</h4> <p data-v-2f2fbab0="">NTD $0.00</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">債券</h4> <p data-v-2f2fbab0="">NTD $208,054,606.62</p></div>, <div class="td cash" data-v-2f2fbab0=""><!-- --> <h4 data-v-2f2fbab0="">現金</h4> <p data-v-2f2fbab0="">CNH $768,508.16</p></div>, <div class="td cash" data-v-2f2fbab0=""><!-- --> <h4 data-v-2f2fbab0="">現金</h4> <p data-v-2f2fbab0="">NTD $718,177.00</p></div>, <div class="td cash" data-v-2f2fbab0=""><!-- --> <h4 data-v-2f2fbab0="">應收利息</h4> <p data-v-2f2fbab0="">CNH $788,440.68</p></div>, <div class="td" data-v-2f2fbab0="">名稱</div>, <div class="td" data-v-2f2fbab0="">元大中國國債及政策性金融債3至5年期債券ETF基金</div>, <div class="td" data-v-2f2fbab0="">彭博中國國債及政策性 金融債 3-5 年期債券指數</div>, <div class="td" data-v-2f2fbab0="">差 ...
# [<div class="td" data-v-748178ef=""><h4 data-v-748178ef="">已發行受益權單位總數</h4> <p data-v-748178ef="">17,566,000</p></div>, <div class="td" data-v-748178ef=""><h4 data-v-748178ef="">與前日已發行單位差異數</h4> <p data-v-748178ef="">0.00</p></div>, <div class="td" data-v-748178ef=""><h5 data-v-748178ef="">2023/10/11</h5> <h4 data-v-748178ef="">
#           每受益權單位淨資產價值(元)
#         </h4> <p data-v-748178ef="">NTD 31.4161</p></div>, <div class="td" data-v-748178ef=""><h4 data-v-748178ef="">每現金申購單位之受益權單位數</h4> <p data-v-748178ef="">500,000</p></div>, <div class="td" data-v-748178ef=""><h4 data-v-748178ef="">每現金申購單位約當市值(元)</h4> <p data-v-748178ef="">NTD 15,708,027</p></div>, <div class="td" data-v-748178ef=""><h4 data-v-748178ef="">每申購基數之預收申購總價金(元)</h4> <p data-v-748178ef="">NTD 16,970,000</p></div>, <div class="td" data-v-748178ef=""><h5 data-v-748178ef="">2023/10/11</h5> <h4 data-v-748178ef="">
#           每基數申購總價金差異額(元)
#         </h4> <p data-v-748178ef="">NTD -926,734</p></div>, <div class="td" data-v-748178ef=""><h5 data-v-748178ef="">2023/10/11</h5> <h4 data-v-748178ef="">
#           每基數實際申購總價金(元)
#         </h4> <p data-v-748178ef="">NTD 15,713,266</p></div>, <div class="td" data-v-748178ef=""><h5 data-v-748178ef="">2023/10/12</h5> <h4 data-v-748178ef="">預估發行受益權單位數</h4> <p data-v-748178ef="">17,566,000</p></div>, <div class="td" data-v-748178ef=""><h5 data-v-748178ef="">2023/09/30</h5> <h4 data-v-748178ef="">
#           受益人數
#         </h4> <p data-v-748178ef="">1161</p></div>, <div class="td" data-v-4dc52081="">
#             檔數
#           </div>, <div class="td" data-v-4dc52081="">
#             評比
#           </div>, <div class="td" data-v-4dc52081="">
#             比例
#           </div>, <div class="td" data-v-4dc52081="">
#             日期
#           </div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">檔數</span> <span data-v-4dc52081="">32</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">評比</span> <span data-v-4dc52081="">AA</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">比例</span> <span data-v-4dc52081="">33.71</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">日期</span> <span data-v-4dc52081="">20231011</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">檔數</span> <span data-v-4dc52081="">50</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">評比</span> <span data-v-4dc52081="">A</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">比例</span> <span data-v-4dc52081="">54.07</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">日期</span> <span data-v-4dc52081="">20231011</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">檔數</span> <span data-v-4dc52081="">7</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">評比</span> <span data-v-4dc52081="">BBB</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">比例</span> <span data-v-4dc52081="">9.71</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">日期</span> <span data-v-4dc52081="">20231011</span></div>, <div class="td" data-v-4dc52081="">
#             商品代碼
#           </div>, <div class="td" data-v-4dc52081="">
#             商品名稱
#           </div>, <div class="td" data-v-4dc52081="">
#             面額
#           </div>, <div class="td" data-v-4dc52081="">
#             市值
#           </div>, <div class="td" data-v-4dc52081="">
#             商品權重
#           </div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品代碼</span> <span data-v-4dc52081="">EG8763831</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品名稱</span> <span data-v-4dc52081="">GOLDMAN SACHS GROUP INC 6.75% 10/01/2037</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">面額</span> <span data-v-4dc52081="">590000</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">市值</span> <span data-v-4dc52081="">600577.82</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品權重</span> <span data-v-4dc52081="">3.49</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品代碼</span> <span data-v-4dc52081="">BH2539774</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品名稱</span> <span data-v-4dc52081="">WELLS FARGO &amp; COMPANY 5.013% 04/04/2051</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">面額</span> <span data-v-4dc52081="">670000</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">市值</span> <span data-v-4dc52081="">559285.18</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品權重</span> <span data-v-4dc52081="">3.25</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品代碼</span> <span data-v-4dc52081="">ZL3866627</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品名稱</span> <span data-v-4dc52081="">HSBC HOLDINGS PLC 6.332% 03/09/2044</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">面額</span> <span data-v-4dc52081="">400000</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">市值</span> <span data-v-4dc52081="">388820.93</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品權重</span> <span data-v-4dc52081="">2.26</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品代碼</span> <span data-v-4dc52081="">BG9922686</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品名稱</span> <span data-v-4dc52081="">BANK OF AMERICA CORP 4.083% 03/20/2051</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">面額</span> <span data-v-4dc52081="">510000</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">市值</span> <span data-v-4dc52081="">377151.72</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品權重</span> <span data-v-4dc52081="">2.19</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品代碼</span> <span data-v-4dc52081="">BP1127060</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品名稱</span> <span data-v-4dc52081="">JPMORGAN CHASE &amp; CO 3.328% 04/22/2052</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">面額</span> <span data-v-4dc52081="">560000</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">市值</span> <span data-v-4dc52081="">371655.51</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">商品權重</span> <span data-v-4dc52081="">2.16</span></div>, <div class="td" data-v-4dc52081="">
#             名稱
#           </div>, <div class="td" data-v-4dc52081="">
#             比例
#           </div>, <div class="td" data-v-4dc52081="">
#             檔數
#           </div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">名稱</span> <span data-v-4dc52081="">美國</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">比例</span> <span data-v-4dc52081="">83.61</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">檔數</span> <span data-v-4dc52081="">77</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">名稱</span> <span data-v-4dc52081="">英國</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">比例</span> <span data-v-4dc52081="">9.45</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">檔數</span> <span data-v-4dc52081="">7</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">名稱</span> <span data-v-4dc52081="">日本</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">比例</span> <span data-v-4dc52081="">2.49</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">檔數</span> <span data-v-4dc52081="">4</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">名稱</span> <span data-v-4dc52081="">荷蘭</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">比例</span> <span data-v-4dc52081="">1.94</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">檔數</span> <span data-v-4dc52081="">1</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">名稱</span> <span data-v-4dc52081="">現金</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">比例</span> <span data-v-4dc52081="">2.51</span></div>, <div class="td" data-v-4dc52081=""><span class="d-md-none" data-v-4dc52081="">檔數</span> <span data-v-4dc52081="">0</span></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">台幣</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">韓元</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">日圓</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">港幣</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">歐元</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">人民幣</h4></div>, <div class="td border-bottom" data-v-691531c5=""><h4 class="font-weight-bold" data-v-691531c5="">離岸人民幣</h4></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">台幣</h4> <p data-v-691531c5="">32.104</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">韓元</h4> <p data-v-691531c5="">1340.13</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">日圓</h4> <p data-v-691531c5="">148.76</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">港幣</h4> <p data-v-691531c5="">7.8193</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">歐元</h4> <p data-v-691531c5="">0.9434</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">人民幣</h4> <p data-v-691531c5="">7.2986</p></div>, <div class="td" data-v-691531c5=""><h4 class="font-weight-bold d-md-none" data-v-691531c5="">離岸人民幣</h4> <p data-v-691531c5="">7.2987</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">基金淨資產價值</h4> <p data-v-2f2fbab0="">NTD $551,854,394.00</p></div>, <div class="td" data-v-2f2fbab0=""><h4 data-v-2f2fbab0="">每受益權單位淨資產價值(元)</h4> <p data-v-2f2fbab0="">NTD $31.4161</p></div ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/ks/dqhrwlns2r1506smq16l4dth0000gn/T/ipykernel_30581/3995983642.py in <module>
#       6 for i in name:
#       7     url=domain+i
# ----> 8     response = requests.get(url)
#       9     content = BeautifulSoup(response.text, "html.parser")
#      10     table = content.find_all(class_="td")
#
# /opt/anaconda3/lib/python3.9/site-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /opt/anaconda3/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# /opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# /opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     487         try:
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#     491                     url=url,
#
# /opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# /opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /opt/anaconda3/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# /opt/anaconda3/lib/python3.9/http/client.py in getresponse(self)
#    1375         try:
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#    1379                 self.close()
#
# /opt/anaconda3/lib/python3.9/http/client.py in begin(self)
#     318         # read until we get a non-100 response
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#     322                 break
#
# /opt/anaconda3/lib/python3.9/http/client.py in _read_status(self)
#     279
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#     283             raise LineTooLong("status line")
#
# /opt/anaconda3/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# /opt/anaconda3/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /opt/anaconda3/lib/python3.9/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # 永豐

# %%
name=["00857B","00856B","00836B"]
proxy = "10.11.1.78:8080"
proxies = {
    "http": "http://" + proxy,
    "https": "http://" + proxy,
}
domain="https://sitc.sinopac.com/SinopacEtfs/Etfs/Pcf/"
a1=[]
b1=[]
ck=0
for i in name:
    url=domain+i
    response = requests.get(url,proxies=proxies)
    content = BeautifulSoup(response.text, "html.parser")
    table = content.find_all(class_="fl_cell")
    for j in table:
        try:
            h4=j.find("h4").get_text()
            p=j.find("p").get_text()
            if "已發行受益權單位總數" in h4:
                a1.append(p)
            elif "預估發行受益權單位數" in h4:
                b1.append(p)
        except:
            pass
ans=pd.DataFrame()
ans['name']=name
ans["已發行受益權單位總數"]=a1
ans["預估發行受益權單位數"]=b1
ans
# Out:
#      name   已發行受益權單位總數   預估發行受益權單位數
# 0  00857B  154,768,000  154,768,000
# 1  00856B    8,292,000    8,292,000
# 2  00836B  595,041,000  599,041,000

# %% [markdown]
# # 新光

# %%
name=["00775B","00831B","00844B","00867B"]
proxy = "10.11.1.78:8080"
proxies = {
    "http": "http://" + proxy,
    "https": "http://" + proxy,
}
domain="http://etf.skit.com.tw/Home/Pcf/"
a1=[]
b1=[]
ck=0
for i in name:
    url=domain+i
    response = requests.get(url,proxies=proxies)
    content = BeautifulSoup(response.text, "html.parser")
    table = content.find_all("table")
    th=table[0].find_all("th")
    td=table[0].find_all("td")
    for ids,word in enumerate(th):
        if "已發行受益權單位總數" in word.get_text():
            ans=td[ids].get_text().replace('\r\n','').strip()
            a1.append(ans)
        elif "預估發行受益權單位數" in word.get_text():
            b1.append(td[ids].get_text())
ans=pd.DataFrame()
ans['name']=name
ans["已發行受益權單位總數"]=a1
ans["預估發行受益權單位數"]=b1
ans
# Out:
#      name   已發行受益權單位總數   預估發行受益權單位數
# 0  00775B  107,600,000  107,600,000
# 1  00831B   14,100,000   14,100,000
# 2  00844B  285,675,000  285,675,000
# 3  00867B  488,150,000  488,150,000

# %% [markdown]
# # 台新

# %%
name=["13258","14443"]
proxy = "10.11.1.78:8080"
proxies = {
    "http": "http://" + proxy,
    "https": "http://" + proxy,
}
domain="https://www.tsit.com.tw/ETF?Tag=PurchaseTag&KindId=2119&FundId="
a1=[]
b1=[]
ck=0
for i in name:
    url=domain+i
    response = requests.get(url,proxies=proxies)
    content = BeautifulSoup(response.text, "html.parser")
    table = content.find_all("table")
    th=table[0].find_all("th")
    td=table[0].find_all("td")
    th=th[1:]
    for word in range(len(th)):
        if "已發行受益權單位總數" in th[word].get_text():
            a1.append(td[word].get_text())
        elif "預估發行受益權單位數" in th[word].get_text():
            b1.append(td[word].get_text())
ans=pd.DataFrame()
ans['name']=name
ans["已發行受益權單位總數"]=a1
ans["預估發行受益權單位數"]=b1
ans
# Out:
#     name  已發行受益權單位總數  預估發行受益權單位數
# 0  13258   9,267,000   9,767,000
# 1  14443  31,479,000  31,479,000

# %% [markdown]
# # 富邦

# %%
name=["00694B","00695B","00696B","00746B","00740B","00846B","00741B","00785B"]
proxy = "10.11.1.78:8080"
proxies = {
    "http": "http://" + proxy,
    "https": "http://" + proxy,
}
domain="https://websys.fsit.com.tw/FubonETF/Trade/Pcf.aspx?stkId="
a1=[]
b1=[]
ck=0
for i in name:
    url=domain+i+"&lan=TW"
    response = requests.get(url,proxies=proxies)
    content = BeautifulSoup(response.text, "html.parser")
    content = BeautifulSoup(response.text, "html.parser")
    p=content.find_all("p")
    for i in range(len(p)):
        if '已發行受益權單位總數' in p[i].get_text():
            a1.append(p[i+1].get_text())
        elif '預估發行受益權單位數' in p[i].get_text():
            b1.append(p[i+1].get_text())
ans=pd.DataFrame()
ans['name']=name
ans["已發行受益權單位總數"]=a1
ans["預估發行受益權單位數"]=b1
ans
# Out:
#      name     已發行受益權單位總數     預估發行受益權單位數
# 0  00694B     93,076,000     93,076,000
# 1  00695B     25,186,000     25,186,000
# 2  00696B    862,181,000    862,181,000
# 3  00746B  2,141,464,000  2,142,964,000
# 4  00740B  1,112,471,000  1,112,471,000
# 5  00846B     73,850,000     73,850,000
# 6  00741B     11,128,000     11,128,000
# 7  00785B    871,966,000    871,966,000

# %% [markdown]
# # 中信
